# %%
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

body = client_b844105826ea467292f9d8a53be925e7.get_object(Bucket='edx1-donotdelete-pr-rmsy7vzqm6dj4d',Key='MN_18v1.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_1 = pd.read_csv(body)
df_data_1.head()
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (20,23,24,26,64) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   Borough  Block  Lot   CD  CT2010  CB2010  SchoolDist  Council  ZipCode  \
# 0      MN      1   10  101     5.0  1011.0         2.0      1.0  10004.0
# 1      MN      1  101  101     1.0  1001.0         2.0      1.0  10004.0
# 2      MN      1  201  101     1.0  1000.0         2.0      1.0  10004.0
# 3      MN      1  301  101     NaN     NaN         2.0      1.0  10004.0
# 4      MN      1  401  101     NaN     NaN         2.0      1.0  10004.0
#
#   FireComp  ...  ZMCode   Sanborn   TaxMap  EDesigNum  APPBBL APPDate  \
# 0     E007  ...       Y   199 999  10101.0        NaN     0.0     NaN
# 1     E007  ...       Y   199 999  10101.0        NaN     0.0     NaN
# ...

# %%
client_cred = ibm_boto3.client(service_name='s3',
ibm_api_key_id='j6F8sn2qVWVjPrx43UmQkiyEgFx0DIeN_GNqKTFcKKLE',
ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
config=Config(signature_version='oauth'),
endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')

bucket = 'edx1-donotdelete-pr-rmsy7vzqm6dj4d'

# %%
import numpy as np

# %%
#Create a pickle (PKL) file out of the Dataframe:
df_data_1.to_pickle('./df_raw.pkl')
#Upload the pickle (PKL) file:
client_cred.upload_file('./df_raw.pkl',bucket,'df_raw_cos.pkl')

# %%
#Download the file from Cloud Object Store:
client_cred.download_file(Bucket=bucket,Key='df_raw_cos.pkl',Filename='./df_raw_local.pkl')
#Create a Dataframe out of the file:
df = pd.read_pickle('./df_raw_local.pkl')
df.head()
# Out:
#   Borough  Block  Lot   CD  CT2010  CB2010  SchoolDist  Council  ZipCode  \
# 0      MN      1   10  101     5.0  1011.0         2.0      1.0  10004.0
# 1      MN      1  101  101     1.0  1001.0         2.0      1.0  10004.0
# 2      MN      1  201  101     1.0  1000.0         2.0      1.0  10004.0
# 3      MN      1  301  101     NaN     NaN         2.0      1.0  10004.0
# 4      MN      1  401  101     NaN     NaN         2.0      1.0  10004.0
#
#   FireComp  ...  ZMCode   Sanborn   TaxMap  EDesigNum  APPBBL APPDate  \
# 0     E007  ...       Y   199 999  10101.0        NaN     0.0     NaN
# 1     E007  ...       Y   199 999  10101.0        NaN     0.0     NaN
# 2     E007  ...     NaN   199 999  10101.0        NaN     0.0     NaN
# 3     E007  ...     NaN   199 999  10101.0        NaN     0.0     NaN
# 4     E007  ...     NaN  1 99 999  10101.0        NaN     0.0     NaN
#
#   PLUTOMapID FIRM07_Flag PFIRM15_Flag Version
# 0          1         1.0          1.0    18V1
# ...

# %%
#Download the file from Cloud Object Store:
client_cred.download_file(Bucket=bucket,Key='BK_18v1.csv',Filename='BK_18v1.csv')
#Create a Dataframe out of the file:
df_BK = pd.read_csv('BK_18v1.csv')
df_BK.head()
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (19,20,22,23,24,25,26,64,65,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   Borough  Block   Lot   CD  CT2010  CB2010  SchoolDist  Council  ZipCode  \
# 0      BK      1     1  302    21.0     NaN        13.0     33.0  11201.0
# 1      BK      1    50  302    21.0  2000.0        13.0     33.0  11201.0
# 2      BK      1  7501  302    21.0  2000.0        13.0     33.0  11201.0
# 3      BK      3     1  302    21.0  3002.0        13.0     33.0  11201.0
# 4      BK      3     5  302    21.0     NaN        13.0     33.0  11201.0
#
#   FireComp  ...  ZMCode  Sanborn   TaxMap  EDesigNum        APPBBL  \
# 0     L118  ...     NaN  302 007  30101.0        NaN  3.000010e+09
# 1     L118  ...     NaN  302 007  30101.0      E-231  0.000000e+00
# ...

# %%
#Download the file from Cloud Object Store:
client_cred.download_file(Bucket=bucket,Key='BX_18v1.csv',Filename='BX_18v1.csv')
#Create a Dataframe out of the file:
df_BX = pd.read_csv('BX_18v1.csv')
df_BX.head()
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (19,20,22,23,64,65,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   Borough  Block  Lot   CD  CT2010  CB2010  SchoolDist  Council  ZipCode  \
# 0      BX   2260    1  201    19.0  1022.0         7.0      8.0  10454.0
# 1      BX   2260    4  201    19.0  1022.0         7.0      8.0  10454.0
# 2      BX   2260   10  201    19.0  1022.0         7.0      8.0  10454.0
# 3      BX   2260   17  201    19.0  1022.0         7.0      8.0  10454.0
# 4      BX   2260   18  201    19.0  1022.0         7.0      8.0  10454.0
#
#   FireComp  ...  ZMCode  Sanborn   TaxMap  EDesigNum  APPBBL APPDate  \
# 0     L029  ...     NaN  209S016  20901.0      E-143     0.0     NaN
# 1     L029  ...     NaN  209S016  20901.0      E-143     0.0     NaN
# ...

# %%
#Download the file from Cloud Object Store:
client_cred.download_file(Bucket=bucket,Key='QN_18v1.csv',Filename='QN_18v1.csv')
#Create a Dataframe out of the file:
df_QN = pd.read_csv('QN_18v1.csv')
df_QN.head()
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (19,20,22,23,64,65,77) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   Borough  Block  Lot   CD  CT2010  CB2010  SchoolDist  Council  ZipCode  \
# 0      QN      6    1  402     1.0     NaN        30.0     26.0  11101.0
# 1      QN      6    3  402     1.0  1015.0        30.0     26.0  11101.0
# 2      QN      6    8  402     1.0  1011.0        30.0     26.0  11101.0
# 3      QN      6   20  402     1.0     NaN        30.0     26.0  11101.0
# 4      QN      6   30  402     1.0     NaN        30.0     26.0  11101.0
#
#   FireComp  ...  ZMCode  Sanborn   TaxMap  EDesigNum        APPBBL  \
# 0     L115  ...       Y  401 011  40101.0        NaN  4.000060e+09
# 1     L115  ...     NaN  401 011  40101.0        NaN  0.000000e+00
# ...

# %%
#Download the file from Cloud Object Store:
client_cred.download_file(Bucket=bucket,Key='SI_18v1.csv',Filename='SI_18v1.csv')
#Create a Dataframe out of the file:
df_SI = pd.read_csv('SI_18v1.csv')
df_SI.head()
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (19,20,22,23,24,64,65,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   Borough  Block  Lot   CD  CT2010  CB2010  SchoolDist  Council  ZipCode  \
# 0      SI      1   10  501     3.0  2000.0        31.0     49.0  10301.0
# 1      SI      1   17  501     3.0     NaN        31.0     49.0  10301.0
# 2      SI      1   18  501     3.0     NaN        31.0     49.0  10301.0
# 3      SI      1   19  501     3.0     NaN        31.0     49.0  10301.0
# 4      SI      1   21  501     3.0     NaN        31.0     49.0  10301.0
#
#   FireComp  ...  ZMCode  Sanborn   TaxMap  EDesigNum  APPBBL APPDate  \
# 0     L078  ...     NaN  501 017  50101.0        NaN     0.0     NaN
# 1     L078  ...     NaN  501 017  50101.0        NaN     0.0     NaN
# ...

# %%
#Download the file from Cloud Object Store:
client_cred.download_file(Bucket=bucket,Key='MN_18v1.csv',Filename='MN_18v1.csv')
#Create a Dataframe out of the file:
df_MN = pd.read_csv('MN_18v1.csv')
df_MN.head()
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (20,23,24,26,64) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   Borough  Block  Lot   CD  CT2010  CB2010  SchoolDist  Council  ZipCode  \
# 0      MN      1   10  101     5.0  1011.0         2.0      1.0  10004.0
# 1      MN      1  101  101     1.0  1001.0         2.0      1.0  10004.0
# 2      MN      1  201  101     1.0  1000.0         2.0      1.0  10004.0
# 3      MN      1  301  101     NaN     NaN         2.0      1.0  10004.0
# 4      MN      1  401  101     NaN     NaN         2.0      1.0  10004.0
#
#   FireComp  ...  ZMCode   Sanborn   TaxMap  EDesigNum  APPBBL APPDate  \
# 0     E007  ...       Y   199 999  10101.0        NaN     0.0     NaN
# 1     E007  ...       Y   199 999  10101.0        NaN     0.0     NaN
# ...

# %%
#Download the file from Cloud Object Store:
client_cred.download_file(Bucket=bucket,Key='311_Service_Requests_from_2010_to_Present_min.csv',Filename='311_Service_Requests_from_2010_to_Present_min.csv')
#Create a Dataframe out of the file:
df_311 = pd.read_csv('311_Service_Requests_from_2010_to_Present_min.csv')
df_311.head()
# Out:
#    Unnamed: 0  Unique Key            Created Date Closed Date  \
# 0           0    45531130  02/02/2020 06:09:17 AM         NaN
# 1           1    45529784  02/02/2020 02:15:24 PM         NaN
# 2           2    45527528  02/02/2020 02:27:41 AM         NaN
# 3           3    45530329  02/02/2020 12:13:18 PM         NaN
# 4           4    45528814  02/02/2020 01:59:44 PM         NaN
#
#          Complaint Type         Location Type  Incident Zip  \
# 0        HEAT/HOT WATER  RESIDENTIAL BUILDING       10019.0
# 1  UNSANITARY CONDITION  RESIDENTIAL BUILDING       11204.0
# 2        HEAT/HOT WATER  RESIDENTIAL BUILDING       11372.0
# 3        HEAT/HOT WATER  RESIDENTIAL BUILDING       10458.0
# 4             APPLIANCE  RESIDENTIAL BUILDING       11209.0
#
#           Incident Address         Street Name Address Type             City  \
# 0     426 WEST   52 STREET    WEST   52 STREET      ADDRESS         NEW YORK
# ...

# %%
df_311.size
# Out:
# 96317488

# %%
df_311.dtypes
# Out:
# Unnamed: 0                  int64
# Unique Key                  int64
# Created Date               object
# Closed Date                object
# Complaint Type             object
# Location Type              object
# Incident Zip              float64
# Incident Address           object
# Street Name                object
# Address Type               object
# City                       object
# Status                     object
# Resolution Description     object
# Borough                    object
# Latitude                  float64
# Longitude                 float64
# dtype: object

# %%
df_311['Created Date'] = pd.to_datetime(df_311['Created Date'])
df_311.head()
# Out:
#    Unnamed: 0  Unique Key        Created Date Closed Date  \
# 0           0    45531130 2020-02-02 06:09:17         NaN
# 1           1    45529784 2020-02-02 14:15:24         NaN
# 2           2    45527528 2020-02-02 02:27:41         NaN
# 3           3    45530329 2020-02-02 12:13:18         NaN
# 4           4    45528814 2020-02-02 13:59:44         NaN
#
#          Complaint Type         Location Type  Incident Zip  \
# 0        HEAT/HOT WATER  RESIDENTIAL BUILDING       10019.0
# 1  UNSANITARY CONDITION  RESIDENTIAL BUILDING       11204.0
# 2        HEAT/HOT WATER  RESIDENTIAL BUILDING       11372.0
# 3        HEAT/HOT WATER  RESIDENTIAL BUILDING       10458.0
# 4             APPLIANCE  RESIDENTIAL BUILDING       11209.0
#
#           Incident Address         Street Name Address Type             City  \
# 0     426 WEST   52 STREET    WEST   52 STREET      ADDRESS         NEW YORK
# 1           1751 67 STREET           67 STREET      ADDRESS         BROOKLYN
# ...

# %%
df_311.dtypes
# Out:
# Unnamed: 0                         int64
# Unique Key                         int64
# Created Date              datetime64[ns]
# Closed Date                       object
# Complaint Type                    object
# Location Type                     object
# Incident Zip                     float64
# Incident Address                  object
# Street Name                       object
# Address Type                      object
# City                              object
# Status                            object
# Resolution Description            object
# Borough                           object
# Latitude                         float64
# Longitude                        float64
# dtype: object

# %%
df_311_date=df_311 ['Created Date']

# %%
df_311_date.head()
# Out:
# 0   2020-02-02 06:09:17
# 1   2020-02-02 14:15:24
# 2   2020-02-02 02:27:41
# 3   2020-02-02 12:13:18
# 4   2020-02-02 13:59:44
# Name: Created Date, dtype: datetime64[ns]

# %%
df_311_date.min(skipna=True)
# Out:
# Timestamp('2010-01-01 00:00:00')

# %%
df_311_date.max(skipna=True)
# Out:
# Timestamp('2020-02-02 23:58:57')

# %%
df_311.sort_values (by='Created Date', ascending = True)
# Out:
#         Unnamed: 0  Unique Key        Created Date             Closed Date  \
# 252214      252214    15636509 2010-01-01 00:00:00  01/06/2010 12:00:00 AM
# 251419      251419    15635215 2010-01-01 00:00:00  01/15/2010 12:00:00 AM
# 251420      251420    15635216 2010-01-01 00:00:00  02/16/2010 12:00:00 AM
# 251421      251421    15635217 2010-01-01 00:00:00  01/26/2010 12:00:00 AM
# 251422      251422    15635218 2010-01-01 00:00:00  01/10/2010 12:00:00 AM
# 251423      251423    15635219 2010-01-01 00:00:00  01/16/2010 12:00:00 AM
# 251424      251424    15635220 2010-01-01 00:00:00  01/02/2010 12:00:00 AM
# 251418      251418    15635214 2010-01-01 00:00:00  01/07/2010 12:00:00 AM
# 251425      251425    15635221 2010-01-01 00:00:00  01/07/2010 12:00:00 AM
# 251427      251427    15635223 2010-01-01 00:00:00  01/02/2010 12:00:00 AM
# 251428      251428    15635224 2010-01-01 00:00:00  02/05/2010 12:00:00 AM
# ...

# %%
df_311_date = df_311_date.sort_values(ascending = True)
df_311_date.head()

#df_311_date = df_311_date.sort_values(ascending = False)
# Out:
# 252214   2010-01-01
# 251414   2010-01-01
# 251420   2010-01-01
# 251273   2010-01-01
# 251422   2010-01-01
# Name: Created Date, dtype: datetime64[ns]

# %%
#Unique Zip Codes in Bronx PLUTO data
df_BX['ZipCode'].nunique()
# Out:
# 26

# %%
#df_data_QN.size

#Unique ZipCode in Queens PLUTO data
df_QN['ZipCode'].nunique()
#ZipCodes and counts in Queens PLUTO data
#df_data_QN["Zipcode"].value_counts()
# Out:
# 65

# %%
#Unempty records count
df_311.isnull()
# Out:
#          Unnamed: 0  Unique Key  Created Date  Closed Date  Complaint Type  \
# 0             False       False         False         True           False
# 1             False       False         False         True           False
# 2             False       False         False         True           False
# 3             False       False         False         True           False
# 4             False       False         False         True           False
# 5             False       False         False         True           False
# 6             False       False         False         True           False
# 7             False       False         False         True           False
# 8             False       False         False         True           False
# 9             False       False         False         True           False
# 10            False       False         False         True           False
# ...

# %%
df_311.shape
# Out:
# (6019843, 16)

# %%
df_311.isnull().sum()
# Out:
# Unnamed: 0                     0
# Unique Key                     0
# Created Date                   0
# Closed Date               126657
# Complaint Type                 0
# Location Type              52824
# Incident Zip               80697
# Incident Address           52825
# Street Name                52825
# Address Type               84765
# City                       80274
# Status                         0
# Resolution Description      7826
# Borough                        0
# Latitude                   80671
# Longitude                  80671
# dtype: int64

# %%
df_311.count()
# Out:
# Unnamed: 0                6019843
# Unique Key                6019843
# Created Date              6019843
# Closed Date               5893186
# Complaint Type            6019843
# Location Type             5967019
# Incident Zip              5939146
# Incident Address          5967018
# Street Name               5967018
# Address Type              5935078
# City                      5939569
# Status                    6019843
# Resolution Description    6012017
# Borough                   6019843
# Latitude                  5939172
# Longitude                 5939172
# dtype: int64

# %%
df_311.nunique()
# Out:
# Unnamed: 0                6019843
# Unique Key                6019843
# Created Date              1675132
# Closed Date                757706
# Complaint Type                 30
# Location Type                   5
# Incident Zip                  202
# Incident Address           182600
# Street Name                  6825
# Address Type                    1
# City                           89
# Status                          5
# Resolution Description        340
# Borough                         6
# Latitude                   180072
# Longitude                  180072
# dtype: int64

# %%
#Counts for each complaint type 
df_311['Complaint Type'].value_counts()
# Out:
# HEAT/HOT WATER            1261574
# HEATING                    887850
# PLUMBING                   711130
# GENERAL CONSTRUCTION       500863
# UNSANITARY CONDITION       451643
# PAINT - PLASTER            361257
# PAINT/PLASTER              346438
# ELECTRIC                   307310
# NONCONST                   260890
# DOOR/WINDOW                205278
# WATER LEAK                 193631
# GENERAL                    151308
# FLOORING/STAIRS            137402
# APPLIANCE                  112831
# HPD Literature Request      52824
# SAFETY                      51529
# OUTSIDE BUILDING             7142
# ELEVATOR                     6725
# Unsanitary Condition         5499
# CONSTRUCTION                 5078
# General                      1163
# Safety                        424
# STRUCTURAL                     16
# Plumbing                       11
# AGENCY                          9
# Outside Building                6
# VACANT APARTMENT                6
# ...

# %%
df_311_heat = df_311.replace({'Complaint Type': 'HEAT/HOT WATER'},{'Complaint Type':'HEATING'}, regex=True)
df_311_heat = df_311_heat[(df_311_heat['Complaint Type'] == 'HEATING')]

# %%
df_311_heat.head()
# Out:
#    Unnamed: 0  Unique Key        Created Date Closed Date Complaint Type  \
# 0           0    45531130 2020-02-02 06:09:17         NaN        HEATING
# 2           2    45527528 2020-02-02 02:27:41         NaN        HEATING
# 3           3    45530329 2020-02-02 12:13:18         NaN        HEATING
# 5           5    45530344 2020-02-02 07:52:08         NaN        HEATING
# 7           7    45527939 2020-02-02 09:00:54         NaN        HEATING
#
#           Location Type  Incident Zip         Incident Address  \
# 0  RESIDENTIAL BUILDING       10019.0     426 WEST   52 STREET
# 2  RESIDENTIAL BUILDING       11372.0          87-15 37 AVENUE
# 3  RESIDENTIAL BUILDING       10458.0  2405 SOUTHERN BOULEVARD
# 5  RESIDENTIAL BUILDING       10456.0       1131 MORRIS AVENUE
# 7  RESIDENTIAL BUILDING       11372.0          37-20 81 STREET
#
#           Street Name Address Type             City Status  \
# 0    WEST   52 STREET      ADDRESS         NEW YORK   Open
# ...

# %%
df_311_heat["Closed Date"].count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-78-57941bb9f8f2> in <module>
# ----> 1 df_311_heat["Closed Date"].count()
#
# NameError: name 'df_311_heat' is not defined

# %%
df_311_heat.shape
# Out:
# (2149424, 16)

# %%
df_311_heat['Borough'].value_counts()
# Out:
# BRONX            606133
# BROOKLYN         574845
# MANHATTAN        423039
# Unspecified      282917
# QUEENS           244122
# STATEN ISLAND     18368
# Name: Borough, dtype: int64

# %%
df_311_heat['Incident Zip'].value_counts()
# Out:
# 11226.0    69041
# 10467.0    66073
# 10458.0    65372
# 10468.0    58190
# 10453.0    57818
# 10452.0    49802
# 10457.0    46885
# 10031.0    44777
# 10040.0    44478
# 10456.0    44051
# 11225.0    43077
# 11213.0    40333
# 10462.0    39700
# 10463.0    37702
# 10032.0    36394
# 11212.0    34619
# 10472.0    33718
# 10033.0    33180
# 10460.0    33026
# 11233.0    30814
# 11203.0    29359
# 11221.0    28380
# 10451.0    26537
# 11216.0    26433
# 11207.0    26428
# 10034.0    26375
# 10025.0    24844
# 10466.0    24220
# 10027.0    23740
# 11373.0    23665
#            ...
# 11426.0      326
# 10309.0      317
# 11362.0      315
# 11004.0      248
# 10007.0      227
# 10006.0      202
# 10308.0      195
# 10005.0      181
# 10307.0      178
# 10004.0      161
# 10282.0      155
# 11001.0      121
# 10280.0       72
# 11697.0       66
# 11040.0       57
# 11109.0       23
# 10069.0       23
# 11005.0        8
# 10162.0        5
# 10803.0        4
# 10041.0        3
# ...

# %%
df_311_heat['Incident Address'].value_counts()
# Out:
# 34 ARDEN STREET                   13858
# 89-21 ELMHURST AVENUE             11548
# 3810 BAILEY AVENUE                 7115
# 1025 BOYNTON AVENUE                5785
# 9511 SHORE ROAD                    5006
# 2090 EAST TREMONT AVENUE           3792
# 72-10 41 AVENUE                    3493
# 888 GRAND CONCOURSE                3251
# 2968 PERRY AVENUE                  2992
# 1711 FULTON STREET                 2794
# 2074 WALLACE AVENUE                2737
# 2750 HOMECREST AVENUE              2722
# 1030 BOYNTON AVENUE                2631
# 97 SHERMAN AVENUE                  2560
# 266 BEDFORD PARK BOULEVARD         2530
# 2040 BRONXDALE AVENUE              2480
# 1425 DR M L KING JR BOULEVARD      2353
# 750 GRAND CONCOURSE                2266
# 2176 TIEBOUT AVENUE                2209
# 30 BUCHANAN PLACE                  2033
# 957 WOODYCREST AVENUE              1895
# 3605 SEDGWICK AVENUE               1876
# 2856 WEBB AVENUE                   1823
# ...

# %%
df_311_heat['Closed Date'].count()
# Out:
# 2133429

# %%
df_BK.columns
# Out:
# Index(['Borough', 'Block', 'Lot', 'CD', 'CT2010', 'CB2010', 'SchoolDist',
#        'Council', 'ZipCode', 'FireComp', 'PolicePrct', 'HealthCenterDistrict',
#        'HealthArea', 'SanitBoro', 'SanitDistrict', 'SanitSub', 'Address',
#        'ZoneDist1', 'ZoneDist2', 'ZoneDist3', 'ZoneDist4', 'Overlay1',
#        'Overlay2', 'SPDist1', 'SPDist2', 'SPDist3', 'LtdHeight', 'SplitZone',
#        'BldgClass', 'LandUse', 'Easements', 'OwnerType', 'OwnerName',
#        'LotArea', 'BldgArea', 'ComArea', 'ResArea', 'OfficeArea', 'RetailArea',
#        'GarageArea', 'StrgeArea', 'FactryArea', 'OtherArea', 'AreaSource',
#        'NumBldgs', 'NumFloors', 'UnitsRes', 'UnitsTotal', 'LotFront',
#        'LotDepth', 'BldgFront', 'BldgDepth', 'Ext', 'ProxCode', 'IrrLotCode',
#        'LotType', 'BsmtCode', 'AssessLand', 'AssessTot', 'ExemptLand',
#        'ExemptTot', 'YearBuilt', 'YearAlter1', 'YearAlter2', 'HistDist',
#        'Landmark', 'BuiltFAR', 'ResidFAR', 'CommFAR', 'FacilFAR', 'BoroCode',
# ...
